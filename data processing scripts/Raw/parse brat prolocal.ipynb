# %%
import csv, requests, json, collections, os
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import re
from numpy.random import randint
regex = re.compile('[^a-zA-Z0-9-_]')
import xlwt 
from xlwt import Workbook
import pandas as pd
from os import listdir
from os.path import isfile, join
# from nltk.tokenize import word_tokenize
# from nltk import pos_tag
import stanza
nlp = stanza.Pipeline('en',verbose=False, processors='tokenize,pos,lemma')

# %%
category_properties = {}
category_properties['Hardware-Devices'] = ['notRelevant','isPowered','isConnected','isSetup','isUsed']
category_properties['Software-Device-Drivers'] = ['notRelevant','isInstalled','isRelatedDeviceConnected','isSettingsChanged']
category_properties['Software-OS-Related'] = ['notRelevant','isOpened','isSettingsChanged']
category_properties['Software-Other'] = ['notRelevant','isInstalled','isOpened','isSettingsChanged']
category_properties['Hardware-Other'] = ['']

property_event = {}
property_event['notRelevant'] = True
property_event['isPowered'] = False
property_event['isConnected'] = False
property_event['isSetup'] = True
property_event['isUsed'] = True
property_event['isInstalled'] = False
property_event['isRelatedDeviceConnected'] = False
property_event['isSettingsChanged'] = True
property_event['isOpened'] = False

property_values = {}
property_values[True] = ['true','false']
property_values[False] = ['f->t','t->f','noChange','start-T','start-F']

# %%
step_details = []
mentions = {}
entities = {}
ent_variants = {}

# %%
# def process_word(word):
#     w = word
#     cap = False
#     if(w.isupper()):
#         cap = True
#     w = w.lower()
# #     print(w)
#     if('\'s' == w):
#         w=''
#     if('cd' == w):
#         w='CD'
#     w = lemmatizer.lemmatize(w)
# #     print(w)
#     if(not cap):
#         w = w.capitalize()
#     else:
#         w = w.upper()
#     w = regex.sub('', w)
#     if(len(w)<2 and w!= 'X'):
#         w=''
#     return w

def get_line(offset):
    for i, step in enumerate(step_details):
        if(int(offset)<step[2]):
            return i-2
    return len(step_details)-1
def clean_text(ent_text):
    tokens=nlp(ent_text)
    tokens = [w for sent in tokens.sentences for w in sent.words]
    lemmas = [token.lemma.lower().strip() for token in tokens]
    ent_text = ' '.join(lemmas)
    return ent_text
def get_text(mention):
    text = mentions[mention][-2]
    while(entities[text][0] != '' and entities[text][0] != text):
        text = entities[text][0]
    return text
def get_base_ent(text):
    while(entities[text][0] != '' and entities[text][0] != text):
        text = entities[text][0]
    return text
def state_change(new_state, prev_state):
    if(new_state==prev_state):
        return 'None'
    elif(new_state=='True'):
        return 'True'
    elif(new_state=='False'):
        return 'False'
    else:
        return 'None'
def get_indexes(sent_tokens, ent_text,verb=False):
    indexes = ['0' for _ in sent_tokens]
    if verb:
        indexes = ['1' if token.pos=='VERB' else '0' for token in sent_tokens]
    else:
        for ent in ent_variants[ent_text]:
            ent_tokens = nlp(ent)
            ent_tokens = [w for sent in ent_tokens.sentences for w in sent.words]
            for i in range(len(sent_tokens)-len(ent_tokens)+1):
                if(all(ent_tokens[j].lemma.lower().strip()==sent_tokens[i+j].lemma.lower().strip() for j in range(len(ent_tokens)))):
                    for j in range(len(ent_tokens)):
                        indexes[i+j]='1'
    return indexes
def process_sent(sent:str,ent_text:str):
    tokens=nlp(sent)
    tokens = [w for sent in tokens.sentences for w in sent.words]
    lemmas = [token.lemma.lower().strip() for token in tokens]
    ent_spans = get_indexes(tokens,ent_text)
    verb_spans = get_indexes(tokens, ent_text, verb=True)
    return [lemmas,ent_spans,verb_spans]

# %%
def parse_annotations(out_file,doc_id=1,folder='config/',file='monitor',filter_prop=''):
    global entities, mentions, step_details, ent_variants
    try:
        config_file = folder+file+'.ann'
        text_file = folder+file+'.txt'
        annotations = open(config_file,'r',encoding='utf-8').readlines()
        raw_text = open(text_file,'r',encoding='utf-8').read().strip()
        steps = raw_text.split('\n\n')

        step_details = []
        start = 0
        start2 = 0
        for i, step in enumerate(steps):
            length = len(step)
            newlines = step.count('\n')
            step_details.append([i,step,start,start2,length,newlines])
            start+=length+newlines+4 ### accounting for '\n' diff in Brat
            start2+=2+length
        #     if(i==3):
        #         print(step,'\n\n',newlines)
        num_steps = len(step_details) - 1

        entities = {} #base-entity, mentions
        mentions = {} #ent_id, line_no, ent_cat, start, end, ent_text, properties
        for line in annotations:
            line=line.strip()
            if(line[0]=='T'): ### entities
                ent_id, ent_cat, ent_text = line.split('\t')
                ent_text = clean_text(ent_text)
                ent_cat, start, end = ent_cat.split(' ')
                line_no = get_line(start)
                start,end,line_no = int(start),int(end),int(line_no)
                mentions[ent_id] = [ent_id, line_no,ent_cat,start,end,ent_text,{}]
                if(ent_text not in entities):
                    entities[ent_text]=['',[]]
                entities[ent_text][1].append(ent_id)
        #         print(ent_id,ent_cat,start,end,line_no,ent_text,sep='\n')
        #         break
            elif(line[0]=='A'): ### attributes
                atr_id, atr_type = line.split('\t')
                split = atr_type.split(' ')
                if(len(split)==2):
                    split.append('true')
                atr_type, atr_ent, atr_val = split
                mentions[atr_ent][-1][atr_type]=atr_val
        #         print(atr_id,atr_type, atr_ent, atr_val,sep='\n')
        #         break
            elif(line[0]=='*'): ### equiv
                _, rel_type = line.split('\t')
                rels = rel_type.split(' ')
                rel_type, ent1, ent2 = rels[0], rels[1], rels[2]
                text1, text2 = get_text(ent1), get_text(ent2)
                if(text1==text2):
                    continue
                base, other = text2, text1
                if(len(text1)<=len(text2)):
                    base, other = text1, text2
                entities[other][0]=base
        #         print(entities[other][0],base,sep=',')
            elif(line[0]=='R'): ### relation- subpart
                rel_id, rel_type = line.split('\t')
                rel_type, sub, main = rel_type.split(' ')
                sub, main = sub.split(':')[1],main.split(':')[1]
                sub, main = get_text(sub), get_text(main)
                entities[sub][0] = main
        #         print(rel_id,rel_type,sub,main,sep=',\t')
            else:
                print(line)

        merged_ents = {} ### merge entities with base-subpart-equiv
        ent_variants = {}
        for ent in entities:
            base_ent = get_base_ent(ent)
            if(base_ent not in merged_ents):
                merged_ents[base_ent] = {}
                ent_variants[base_ent] = set()
            ent_variants[base_ent].add(ent)
            for mention_id in entities[ent][1]:
                mention = mentions[mention_id]
                line_no = mention[1]
                if(line_no not in merged_ents[base_ent]):
                    merged_ents[base_ent][line_no] = mention
                else:
                    merged_ents[base_ent][line_no][-1].update(mention[-1])
    #     print(ent_variants)

        clean_ents = []
        for ent in merged_ents:
            if(all(merged_ents[ent][line_no][-1]=={} for line_no in merged_ents[ent])):
                clean_ents.append(ent)
        for ent in clean_ents:
            del merged_ents[ent]

        step_wise_properties = {}

        for ent in merged_ents:
            mention = mentions[entities[ent][1][0]]
            category = mention[2]
            if(category == 'Hardware-Other'):
                continue
            properties = category_properties[category]
            ent_properties = {}
            for prop in properties:
                prop_val = ['']*(num_steps+1)
                prop_val[0]='False'
        #         print(sorted(merged_ents[ent]))
        #         break
        #         ent_mentions = [mentio]
        #         ent_mentions = sorted(merged_ents[ent])
                if(property_event[prop]):
                    for step_no in range(0,num_steps):
                        if(step_no in merged_ents[ent] and prop in merged_ents[ent][step_no][-1]):
                            val = merged_ents[ent][step_no][-1][prop].capitalize()
                            prop_val[step_no+1] = val
                        else:
                            prop_val[step_no+1] = 'False'
                else:
                    for step_no in range(0,num_steps):
                        if(step_no in merged_ents[ent] and prop in merged_ents[ent][step_no][-1]):
                            val = merged_ents[ent][step_no][-1][prop]
                            if(val=='f->t' and prop_val[step_no]=='False'):
                                prop_val[step_no+1] = 'True'
                            elif(val=='t->f' and prop_val[step_no]=='True'):
                                prop_val[step_no+1] = 'False'
                            elif(val=='t->f' and all(val=='False' for val in prop_val[:step_no])):
                                for i in range(step_no+1):
                                    prop_val[i] = 'True'
                                prop_val[step_no+1] = 'False'
                            elif(val=='start-T'):
                                for i in range(step_no+2):
                                    prop_val[step_no+1] = 'True'
                            elif(val=='start-F'):
                                for i in range(step_no+2):
                                    prop_val[step_no+1] = 'False'
                            else:
                                prop_val[step_no+1] = prop_val[step_no]
                        else:
                            prop_val[step_no+1] = prop_val[step_no]
                if not((filter_prop != '' and prop!=filter_prop) or all(val=='False' for val in prop_val)):
                    ent_properties[prop]=prop_val
        #     print(ent,category,ent_properties,sep='\n')
        #     break
            step_wise_properties[ent]=ent_properties
        # print(step_wise_properties)

#         df = pd.DataFrame({'Steps':steps})
#         for ent in step_wise_properties:
#             for prop in step_wise_properties[ent]:
#                 if(filter_prop==''):
#                     df[ent+'___'+prop] = step_wise_properties[ent][prop]
#                 else:
#                     df[ent] = step_wise_properties[ent][prop]

#         headers = list(df.columns)[1:]
    #     print(df['Steps'])
        for ent in step_wise_properties:
            for prop in step_wise_properties[ent]:
                for step_no in range(len(steps)-1):
                    sent_lemmas, ent_spans, verb_spans = process_sent(steps[step_no+1],ent)
                    if(all(ent_tag=='0' for ent_tag in ent_spans)):
                        continue;
    #                 print(sent_lemmas, ent_spans, verb_spans)
                    print('####'.join(sent_lemmas),','.join(verb_spans),','.join(ent_spans),state_change(step_wise_properties[ent][prop][step_no+1],step_wise_properties[ent][prop][step_no]),sep='\t',file=out_file)
    except:
        print('ERROR')

# %%
# parse_annotations()
# f.close()

# %%
def parse_prop(filter_prop='isOpened'):
#     filter_prop = 'isOpened'
    train_f = open('./annotations/prolocal_annotations_'+filter_prop+'_train.tsv','w',encoding='utf-8')
    dev_f = open('./annotations/prolocal_annotations_'+filter_prop+'_dev.tsv','w',encoding='utf-8')
    test_f = open('./annotations/prolocal_annotations_'+filter_prop+'_test.tsv','w',encoding='utf-8')
    data_folder = './annotations/'
    count = 1
    for folder in [fol for fol in listdir(data_folder) if not isfile(join(data_folder, fol))]:
        folder = data_folder + folder+'/'
        onlyfiles = [f[:-4] for f in listdir(folder) if f.endswith('.txt')]
        for file in onlyfiles:
            rand = randint(0,100)
            print(count, folder, file,rand)
            if(rand<80):
                parse_annotations(out_file=train_f,doc_id=count, folder=folder, file=file, filter_prop=filter_prop)
            elif(rand<90):
                parse_annotations(out_file=dev_f,doc_id=count, folder=folder, file=file, filter_prop=filter_prop)
            else:
                parse_annotations(out_file=test_f,doc_id=count, folder=folder, file=file, filter_prop=filter_prop)
            count+=1
    train_f.close()
    dev_f.close()
    test_f.close()

# %%
parse_prop()
# Out:
# 1 ./annotations/Controllers/ 199_1___Test_Your_PS4_Controller___Steps 10
# 2 ./annotations/Controllers/ 200_1___Connect_an_Xbox_One_Controller_to_an_Xbox_One___Connecting_Wirelessly 20
# 3 ./annotations/Controllers/ 201_1___Disable_the_Green_Light_on_a_Thrustmaster_T.16000M_Joystick___Steps 43
# 4 ./annotations/Controllers/ 202_1___Hack_an_Xbox_Controller_Into_a_PC_Gamepad___Steps 29
# 5 ./annotations/Controllers/ 203_1___Connect_a_Razer_Controller_to_a_PC___Connecting_Wirelessly 44
# 6 ./annotations/Controllers/ 204_1___Use_the_Razer_Hydra___Installing_the_Hydra 97
# 7 ./annotations/Controllers/ 204_2___Use_the_Razer_Hydra___Using_the_Hydra 71
# 8 ./annotations/Headphones/ 161_1___Repair_Dodgy_or_Broken_Headphones___Finding_the_Problem 16
# 9 ./annotations/Headphones/ 161_2___Repair_Dodgy_or_Broken_Headphones___Fixing_the_Cable 38
# 10 ./annotations/Headphones/ 161_3___Repair_Dodgy_or_Broken_Headphones___Fixing_a_Broken_Plug 45
# 11 ./annotations/Headphones/ 162_1___Fix_Earbuds___Soldering_a_Broken_Connection 60
# 12 ./annotations/Headphones/ 163_1___Connect_a_Headset_to_PC___Connecting_via_Bluetooth 91
# 13 ./annotations/Headphones/ 163_2___Connect_a_Headset_to_PC___Changing_Windows_Sound_Settings 18
# 14 ./annotations/Headphones/ 164_1___Keep_Earbuds_from_Falling_Out_of_Your_Ears___Troubleshooting_the_Fit_of_Your_Earbuds 8
# 15 ./annotations/Headphones/ 164_2___Keep_Earbuds_from_Falling_Out_of_Your_Ears___Purchasing_Well-Fitting_Earbuds 98
# 16 ./annotations/Headphones/ 165_1___Clean_a_Headphone_Jack___Cleaning_with_Cotton_Swabs 86
# 17 ./annotations/Headphones/ 166_1___Wear_Headphones___Wearing_In-Ear_Headphones 64
# 18 ./annotations/Headphones/ 167_1___Connect_a_HyperX_Cloud_Headset___Connecting_to_a_PC 88
# 19 ./annotations/Headphones/ 168_1___Pair_Jaybird_Headphones_on_PC_or_Mac___Pairing_Jaybird_Headphones_with_Windows_Bluetooth 52
# 20 ./annotations/Headphones/ 169_1___Use_Computer_Headphones___Plugging_in_Headphones 34
# 21 ./annotations/Headphones/ 170_1___Burn_in_Headphones___Preparing_a_Burn-in_Playlist 56
# 22 ./annotations/Headphones/ 171_1___Keep_Your_Headphones_From_Tangling___Steps 91
# 23 ./annotations/Headphones/ 172_1___Store_Headphones___Wrapping_the_Cord_Properly 83
# 24 ./annotations/Headphones/ 173_1___Test_Earphones___Judging_Sound_Quality 18
# 25 ./annotations/Headphones/ 174_1___Clean_AirPods___Cleaning_Off_Dirt_and_Dust 27
# 26 ./annotations/Headphones/ 175_1___Wrap_a_Headphone_Cord___Doing_a_Crazy_8_Knot 37
# 27 ./annotations/Headphones/ 175_2___Wrap_a_Headphone_Cord___Making_a_DIY_Headphone_Holder 3
# 28 ./annotations/Headphones/ 176_1___Pair_Jawbone_Headsets_and_Speakers___ 8
# 29 ./annotations/Headphones/ 176_2___Pair_Jawbone_Headsets_and_Speakers___How_to_Pair_Jawbone_Era 80
# 30 ./annotations/Headphones/ 176_3___Pair_Jawbone_Headsets_and_Speakers___How_to_Pair_Jawbone_Jambox 82
# 31 ./annotations/Headphones/ 177_1___Make_Tangle_Free_Headphones_with_Embroidery_Floss___Wrapping_the_Headphones 33
# 32 ./annotations/Headphones/ 178_1___Install_Headphones___ 67
# 33 ./annotations/Headphones/ 178_2___Install_Headphones___Installing_Headphones 65
# 34 ./annotations/Headphones/ 179_1___Choose_Bluetooth_Headphones___Selecting_the_Type_of_Bluetooth_Headphones_You_Need 8
# 35 ./annotations/Headphones/ 179_2___Choose_Bluetooth_Headphones___Considering_Your_Purchase_Before_You_Buy 54
# 36 ./annotations/Headphones/ 180_1___Clean_Powerbeats_3___Washing_the_Eartips 92
# 37 ./annotations/Headphones/ 180_2___Clean_Powerbeats_3___Cleaning_Wax_Buildup_on_the_Speaker_Mesh 36
# 38 ./annotations/Headphones/ 181_1___Stop_Your_Headphone_Cords_from_Tangling___Untangling_the_Cords 86
# 39 ./annotations/Headphones/ 182_1___Be_Street_Smart_with_Headphones___Steps 37
# 40 ./annotations/Headphones/ 183_1___Add_a_Headphone_Jack_to_a_BoboVR_Headset___Steps 65
# 41 ./annotations/Headphones/ 184_1___Wash_Earphone_Pads___Cleaning_with_Soapy_Water_Weekly 47
# 42 ./annotations/Keyboards/ 112_1___Turn_On_the_Keyboard_Light_on_an_HP_Pavilion___Turning_on_the_Light 22
# 43 ./annotations/Keyboards/ 112_2___Turn_On_the_Keyboard_Light_on_an_HP_Pavilion___Resetting_a_Malfunctioning_Light 86
# 44 ./annotations/Keyboards/ 113_1___Fix_a_Keyboard_That_Has_the_Wrong_Characters___Using_Windows_10 10
# 45 ./annotations/Keyboards/ 113_2___Fix_a_Keyboard_That_Has_the_Wrong_Characters___Using_macOS 42
# 46 ./annotations/Keyboards/ 113_3___Fix_a_Keyboard_That_Has_the_Wrong_Characters___Using_Windows_8_and_8.1 1
# 47 ./annotations/Keyboards/ 113_4___Fix_a_Keyboard_That_Has_the_Wrong_Characters___Using_Windows_7 6
# 48 ./annotations/Keyboards/ 114_1___Reset_a_Keyboard___On_Windows 68
# 49 ./annotations/Keyboards/ 114_2___Reset_a_Keyboard___On_Mac 3
# 50 ./annotations/Keyboards/ 114_3___Reset_a_Keyboard___Resetting_Language_Settings_on_Windows 14
# 51 ./annotations/Keyboards/ 114_4___Reset_a_Keyboard___Resetting_Language_Settings_on_Mac 36
# 52 ./annotations/Keyboards/ 114_5___Reset_a_Keyboard___Resetting_a_Wireless_Apple_Keyboard 26
# 53 ./annotations/Keyboards/ 115_1___Disable_the_Function_Key___Using_Mac 43
# 54 ./annotations/Keyboards/ 116_1___Fix_a_Jammed_Keyboard_Key___Shaking_Out_the_Keyboard 43
# 55 ./annotations/Keyboards/ 116_2___Fix_a_Jammed_Keyboard_Key___Blowing_Out_the_Keyboard 35
# 56 ./annotations/Keyboards/ 116_3___Fix_a_Jammed_Keyboard_Key___Cleaning_Sticky_Keys 20
# 57 ./annotations/Keyboards/ 116_4___Fix_a_Jammed_Keyboard_Key___Removing_Keys_to_Clean_the_Keypad 73
# 58 ./annotations/Keyboards/ 117_1___Clean_a_Keyboard___Removing_Debris_from_a_Keyboard 43
# 59 ./annotations/Keyboards/ 117_2___Clean_a_Keyboard___Treating_Liquid_Spills 69
# 60 ./annotations/Keyboards/ 117_3___Clean_a_Keyboard___Cleaning_Inside_a_Keyboard 60
# 61 ./annotations/Keyboards/ 118_1___Connect_Wireless_Keyboard_to_PC___Connecting_a_Bluetooth_Keyboard_on_Windows_10 74
# 62 ./annotations/Keyboards/ 118_2___Connect_Wireless_Keyboard_to_PC___Connecting_a_Bluetooth_Keyboard_on_Windows_7 21
# 63 ./annotations/Keyboards/ 119_1___Fix_Sticky_Keyboard_Keys___Cleaning_Your_Keyboard 14
# 64 ./annotations/Keyboards/ 119_2___Fix_Sticky_Keyboard_Keys___Fixing_Hardware_and_Software_Issues 66
# 65 ./annotations/Keyboards/ 120_1___Clean_a_Laptop_Keyboard___Doing_a_Basic_Keyboard_Cleaning 73
# 66 ./annotations/Keyboards/ 120_2___Clean_a_Laptop_Keyboard___Removing_the_Keys 65
# 67 ./annotations/Keyboards/ 120_3___Clean_a_Laptop_Keyboard___Cleaning_a_Liquid_Spill 4
# 68 ./annotations/Keyboards/ 121_1___Reattach_a_Keyboard_Key___Reattaching_a_Key_on_a_Laptop_Keyboard 9
# 69 ./annotations/Keyboards/ 121_2___Reattach_a_Keyboard_Key___ 99
# 70 ./annotations/Keyboards/ 122_1___Use_a_Keyboard_to_Click_Instead_of_a_Mouse___Windows 25
# 71 ./annotations/Keyboards/ 122_2___Use_a_Keyboard_to_Click_Instead_of_a_Mouse___Mac 7
# 72 ./annotations/Keyboards/ 123_1___Repair_Dell_Laptop_Keyboard_Keys___Repairing_a_Loose_Key 20
# 73 ./annotations/Keyboards/ 123_2___Repair_Dell_Laptop_Keyboard_Keys___Repairing_a_Stuck_or_Nonfunctional_Key 97
# 74 ./annotations/Keyboards/ 123_3___Repair_Dell_Laptop_Keyboard_Keys___Reinstalling_the_Retaining_Clip 83
# 75 ./annotations/Keyboards/ 124_1___Extend_Wireless_Range_of_a_Wireless_Keyboard_and_Mouse___Steps 31
# 76 ./annotations/Keyboards/ 125_1___Clean_a_Mac_Keyboard___Removing_Dirt_and_Debris 70
# 77 ./annotations/Keyboards/ 125_2___Clean_a_Mac_Keyboard___Disinfecting_the_Keyboard 32
# 78 ./annotations/Keyboards/ 126_1___Pop_a_Key_Back_Onto_a_Dell_Laptop_Keyboard___Steps 2
# 79 ./annotations/Keyboards/ 127_1___Use_a_Computer_Keyboard___Sitting_at_the_Keyboard 17
# 80 ./annotations/Keyboards/ 127_2___Use_a_Computer_Keyboard___Learning_to_Type 39
# 81 ./annotations/Keyboards/ 127_3___Use_a_Computer_Keyboard___Using_the_Navigation_Keys 30
# 82 ./annotations/Keyboards/ 127_4___Use_a_Computer_Keyboard___Mastering_the_Numeric_Pad 38
# 83 ./annotations/Keyboards/ 128_1___Clean_a_Sticky_Keyboard__Cleaning_Sticky_Debris 44
# 84 ./annotations/Keyboards/ 129_1___Use_the_NumLock_Feature_on_Lenovo_Thinkpads___Laptops_without_a_NumLock_Key 13
# 85 ./annotations/Keyboards/ 130_1___Do_Squared_on_a_Keyboard___Using_Gboard_on_a_Phone_or_Tablet 63
# 86 ./annotations/Keyboards/ 131_1___Clean_a_Mechanical_Keyboard___Taking_Apart_Your_Keyboard 51
# 87 ./annotations/Keyboards/ 132_1___Use_Hacker%27s_Keyboard___ 51
# 88 ./annotations/Keyboards/ 133_1___Add_Another_Language_to_Your_Computer_Keyboard___Steps 49
# 89 ./annotations/Keyboards/ 134_1___Unlock_a_Keypad___Unlocking_Keypads_on_Mac_OS_X 11
# 90 ./annotations/Keyboards/ 135_1___Clean_Under_Laptop_Keyboard_Keys___Putty 74
# 91 ./annotations/Keyboards/ 137_1___Cut_the_Number_Pad_off_a_Keyboard___Steps 48
# 92 ./annotations/Keyboards/ 138_1___Bind_a_Razer_Keyboard___Creating_the_key_bind 71
# 93 ./annotations/Keyboards/ 139_1___Troubleshoot_Mouse_Problems_with_the_Keyboard___Steps 11
# 94 ./annotations/Keyboards/ 140_1___Edit_Gboard_Keyboard_Settings___Using_the_Gboard_App 90
# 95 ./annotations/Keyboards/ 140_2___Edit_Gboard_Keyboard_Settings___Changing_Keyboard_Order_and_Text_Replacement 18
# 96 ./annotations/Keyboards/ 141_1___Clean_a_Keyboard_in_a_Dishwasher___Steps 34
# 97 ./annotations/Keyboards/ 142_1___Change_the_Default_Numlock_State___Steps 40
# 98 ./annotations/Keyboards/ 143_1___Start_Screensaver_with_a_Keyboard_Shortcut_on_Mac___Creating_the_Action 47
# 99 ./annotations/Keyboards/ 143_2___Start_Screensaver_with_a_Keyboard_Shortcut_on_Mac___Creating_the_Keyboard_Shortcut 91
# 100 ./annotations/Keyboards/ 144_1___Fix_a_Dell_Laptop_Key___Fallen_Key_Cap_and_Key_Retainer 77
# 101 ./annotations/Keyboards/ 144_2___Fix_a_Dell_Laptop_Key___Lost_Key 96
# 102 ./annotations/Keyboards/ 145_1___Fix_a_Keyboard___Cleaning_Sticky_Keys 78
# 103 ./annotations/Keyboards/ 145_2___Fix_a_Keyboard___Wiping_the_Circuits 46
# 104 ./annotations/Keyboards/ 146_1___Change_Your_Keyboard_from_US_to_UK_(Windows_XP)___Steps 49
# 105 ./annotations/Keyboards/ 147_1___Move_the_Computer_Mouse_with_the_Keyboard_(Windows)___Steps 64
# 106 ./annotations/Keyboards/ 148_1___Adjust_to_a_New_Computer_Keyboard___Steps 36
# 107 ./annotations/Keyboards/ 149_1___Print_Using_the_Keyboard_on_PC_or_Mac___Steps 67
# 108 ./annotations/Keyboards/ 150_1___Toggle_WiFi_On_and_Off_with_a_Keyboard_Shortcut_on_Mac___Creating_the_Action 34
# 109 ./annotations/Keyboards/ 150_2___Toggle_WiFi_On_and_Off_with_a_Keyboard_Shortcut_on_Mac___Creating_the_Keyboard_Shortcut. 65
# 110 ./annotations/Keyboards/ 151_1___D630_Laptop___Steps 43
# 111 ./annotations/Keyboards/ 152_1___Remove_Most_Liquids_from_a_Standard_Keyboard___Steps 54
# 112 ./annotations/Keyboards/ 153_1___Make_an_Old_Midi_Keyboard_Work_on_a_New_Operating_System___Steps 16
# 113 ./annotations/Keyboards/ 154_1___Hang_a_Keyboard___Adding_an_Under-Desk_Keyboard_Mount 67
# 114 ./annotations/Keyboards/ 154_2___Hang_a_Keyboard___Installing_a_Wall-Mounted_Keyboard_Tray 49
# 115 ./annotations/Keyboards/ 155_1___Make_a_Thin_Keyboard___Steps 34
# 116 ./annotations/Linux/ 554_1___Become_Root_in_Linux___Gaining_Root_Access_in_the_Terminal 34
# 117 ./annotations/Linux/ 554_2___Become_Root_in_Linux___ 77
# 118 ./annotations/Linux/ 554_3___Become_Root_in_Linux___Resetting_the_Root_or_Admin_Password 80
# 119 ./annotations/Linux/ 555_1___Create_and_Edit_Text_File_in_Linux_by_Using_Terminal___Opening_Terminal 52
# 120 ./annotations/Linux/ 555_2___Create_and_Edit_Text_File_in_Linux_by_Using_Terminal___Creating_a_Quick_Text_File 38
# 121 ./annotations/Linux/ 555_3___Create_and_Edit_Text_File_in_Linux_by_Using_Terminal___Using_Vim 97
# 122 ./annotations/Linux/ 555_4___Create_and_Edit_Text_File_in_Linux_by_Using_Terminal___Using_Emacs 49
# 123 ./annotations/Linux/ 556_1___Check_the_IP_Address_in_Linux___Finding_Your_Public_IP_Address 39
# 124 ./annotations/Linux/ 556_2___Check_the_IP_Address_in_Linux___Finding_Your_Private_IP_Address 44
# 125 ./annotations/Linux/ 557_1___Take_a_Screenshot_in_Linux___Using_Gnome_Screenshot 57
# 126 ./annotations/Linux/ 557_2___Take_a_Screenshot_in_Linux___Using_GIMP 1
# 127 ./annotations/Linux/ 557_3___Take_a_Screenshot_in_Linux___Using_ImageMagick 94
# 128 ./annotations/Linux/ 557_4___Take_a_Screenshot_in_Linux___Using_Shutter 70
# 129 ./annotations/Linux/ 558_1___Add_or_Change_the_Default_Gateway_in_Linux___Editing_Your_Configuration_File 53
# 130 ./annotations/Linux/ 559_1___Find_a_File_in_Linux___ 57
# 131 ./annotations/Linux/ 560_1___Install_XAMPP_on_Linux___Installing_XAMPP 66
# 132 ./annotations/Linux/ 560_2___Install_XAMPP_on_Linux___Running_XAMPP 10
# 133 ./annotations/Linux/ 561_1___Ping_in_Linux___Using_the_Ping_Command 94
# 134 ./annotations/Linux/ 562_1___Install_Linux___Installing_Any_Linux_Distribution 60
# 135 ./annotations/Linux/ 563_1___Execute_INSTALLsh_Files_in_Linux_Using_Terminal___Steps 30
# 136 ./annotations/Linux/ 564_1___Change_the_Timezone_in_Linux___Using_the_Command_Line 17
# 137 ./annotations/Linux/ 564_2___Change_the_Timezone_in_Linux___Using_the_Graphical_User_Interface_in_Ubuntu 39
# 138 ./annotations/Linux/ 564_3___Change_the_Timezone_in_Linux___Using_the_Graphical_User_Interface_in_Mint 52
# 139 ./annotations/Linux/ 565_1___Create_an_ISO_File_in_Linux___Creating_an_ISO_from_Files 40
# 140 ./annotations/Linux/ 565_2___Create_an_ISO_File_in_Linux___Ripping_an_ISO_from_a_CD 46
# 141 ./annotations/Linux/ 566_1___Install_Tor_on_Linux___Downloading_the_Tor_Package 7
# 142 ./annotations/Linux/ 566_2___Install_Tor_on_Linux___Installing_Tor 65
# 143 ./annotations/Linux/ 567_1___Use_Wine_on_Linux___Installing_Wine 42
# 144 ./annotations/Linux/ 567_2___Use_Wine_on_Linux___Setting_up_Wine 27
# 145 ./annotations/Linux/ 567_3___Use_Wine_on_Linux___Installing_a_Program 62
# 146 ./annotations/Linux/ 568_1___Restart_Services_in_Linux___Steps 45
# 147 ./annotations/Mac/ 1000_1___Connect_AirPods_to_a_Macbook___Steps 7
# 148 ./annotations/Mac/ 1001_1___Begin_Using_a_Mac___The_Basics 39
# 149 ./annotations/Mac/ 1001_2___Begin_Using_a_Mac___Using_Applications 36
# 150 ./annotations/Mac/ 1002_1___Set_Up_a_VPN_on_a_Mac___Entering_VPN_Settings_Manually 92
# 151 ./annotations/Mac/ 1002_2___Set_Up_a_VPN_on_a_Mac___Using_a_VPN_Settings_File 99
# 152 ./annotations/Mac/ 1002_3___Set_Up_a_VPN_on_a_Mac___Using_Shimo_on_macOS_Sierra 9
# 153 ./annotations/Mac/ 1003_1___Edit_Images_on_a_Mac___Arranging_the_Image 64
# 154 ./annotations/Mac/ 1003_2___Edit_Images_on_a_Mac___Adding_Shapes_to_the_Image 78
# 155 ./annotations/Mac/ 1004_1___Manage_Documents_on_a_Mac___Steps 58
# 156 ./annotations/Mac/ 1005_1___Unzip_a_Zip_File_on_a_Mac___Steps 42
# 157 ./annotations/Mac/ 1006_1___Use_Emoji_on_Facebook_on_a_PC_or_Mac___Steps 7
# 158 ./annotations/Mac/ 1007_1___OpenaTARFileonPCorMacUsingaWindowsbasedPC 52
# 159 ./annotations/Mac/ 1008_1___OpenanMPPFileonPCorMacOpeninganMPPwithProjectViewer365 16
# 160 ./annotations/Mac/ 1009_1___Burn_ISO_with_Toast_Titanium___Steps 71
# 161 ./annotations/Mac/ 1010_1___Open_Disk_Image_DMG_Files_That_Are_Not_Allowed_on_a_Mac___Steps 44
# 162 ./annotations/Mac/ 1011_1___Make_a_Ringtone_on_a_Mac_Using_Garageband___Steps 46
# 163 ./annotations/Mac/ 1012_1___Install_RAM_in_a_Mac_Mini___Steps 25
# 164 ./annotations/Mac/ 1013_1___Make_an_Interactive_Desktop_Background___Customizing_Windows_Desktops 21
# 165 ./annotations/Mac/ 1013_2___Make_an_Interactive_Desktop_Background___Customizing_Mac_Desktops 40
# 166 ./annotations/Mac/ 1014_1___Add_a_Yahoo_Account_to_a_Mac___Steps 69
# 167 ./annotations/Mac/ 1015_1___Become_a_Mac_Genius___Steps 18
# 168 ./annotations/Mac/ 1016_1___Stop_Dock_Apps_from_Bouncing_on_a_Mac___Steps 83
# 169 ./annotations/Mac/ 1017_1___Customize_Your_Mac_Using_the_Terminal___Using_Terminal_Commands 20
# 170 ./annotations/Mac/ 1018_1___Change_the_System_Language_on_a_Mac___Steps 25
# 171 ./annotations/Mac/ 1019_1___Set_a_Keyboard_Shortcut_to_Open_Spotlight___Setting_a_Custom_Keyboard_Shortcut 75
# 172 ./annotations/Microphones/ 156_1___Connect_a_Microphone_to_a_Computer___Troubleshooting_Common_Problems 40
# 173 ./annotations/Microphones/ 157_1___Use_a_Microphone_on_a_PC___Steps 67
# 174 ./annotations/Microphones/ 158_1___Boost_Microphone_Volume_on_PC_or_Mac___Using_Windows 78
# 175 ./annotations/Microphones/ 158_2___Boost_Microphone_Volume_on_PC_or_Mac___Using_Mac 34
# 176 ./annotations/Microphones/ 159_1___Fix_Skype_Microphone_Problems_on_Android___Fixing_Your_Microphone 46
# 177 ./annotations/Microphones/ 159_2___Fix_Skype_Microphone_Problems_on_Android___Testing_Your_Microphone 73
# 178 ./annotations/Microphones/ 160_1___Fix_Skype_Microphone_Problems_on_PC_or_Mac___Using_Mac 14
# 179 ./annotations/Microphones/ 160_2___Fix_Skype_Microphone_Problems_on_PC_or_Mac___Using_Windows 11
# 180 ./annotations/Monitors/ 10_1___Adjust_Colors_on_an_LCD_Monitor___Adjust_LCD_Monitor_Resolution 57
# 181 ./annotations/Monitors/ 10_2___Adjust_Colors_on_an_LCD_Monitor___Calibrate_the_LCD_Color_Monitor 61
# 182 ./annotations/Monitors/ 11_1___Add_an_Additional_Monitor_to_Your_Computer___Steps 58
# 183 ./annotations/Monitors/ 12_1___Degauss_a_Computer_Monitor___Soldering_Gun_Method 9
# 184 ./annotations/Monitors/ 12_2___Degauss_a_Computer_Monitor___Rigged_Drill_Method 86
# 185 ./annotations/Monitors/ 13_1___Discharge_a_CRT_Monitor___Steps 13
# 186 ./annotations/Monitors/ 14_1___Make_a_Monitor_256_Color___Program_Specific_Change 19
# 187 ./annotations/Monitors/ 15_1___Improve_Image_Quality_on_an_LCD_Monitor___Steps 32
# 188 ./annotations/Monitors/ 16_1___Clean_a_Flat_Panel_Monitor___Steps 98
# 189 ./annotations/Monitors/ 17_1___Extend_a_Netbook_to_an_External_Monitor___Steps 95
# 190 ./annotations/Monitors/ 1_1___Connect_a_Laptop_to_a_Monitor___Connecting_the_Monitor 63
# 191 ./annotations/Monitors/ 1_2___Connect_a_Laptop_to_a_Monitor___Detecting_a_Display_in_Windows 27
# 192 ./annotations/Monitors/ 1_3___Connect_a_Laptop_to_a_Monitor___Detecting_a_Display_in_MacOS 96
# 193 ./annotations/Monitors/ 1_4___Connect_a_Laptop_to_a_Monitor___Adjusting_Display_Settings_on_Windows 83
# 194 ./annotations/Monitors/ 1_5___Connect_a_Laptop_to_a_Monitor___Adjusting_Display_Settings_on_Mac 49
# 195 ./annotations/Monitors/ 2_1___Switch_Monitors_1_and_2_on_a_PC__Steps 24
# 196 ./annotations/Monitors/ 3_1___Use_Your_TV_as_a_Second_Monitor_for_Your_Computer___Connecting_Your_Computer_to_the_TV 49
# 197 ./annotations/Monitors/ 3_2___Use_Your_TV_as_a_Second_Monitor_for_Your_Computer___Changing_Display_Settings_on_Windows 30
# 198 ./annotations/Monitors/ 3_3___Use_Your_TV_as_a_Second_Monitor_for_Your_Computer___Changing_Display_Settings_on_Mac 14
# 199 ./annotations/Monitors/ 4_1___Fix_a_Stuck_Pixel_on_an_LCD_Monitor___Preparing_to_Fix 55
# 200 ./annotations/Monitors/ 4_2___Fix_a_Stuck_Pixel_on_an_LCD_Monitor___Using_Screen-Fixing_Software 63
# 201 ./annotations/Monitors/ 4_3___Fix_a_Stuck_Pixel_on_an_LCD_Monitor___Using_Pressure_and_Heat 71
# 202 ./annotations/Monitors/ 5_1___Repair_LCD_Monitors___Diagnosing_the_Problem 85
# 203 ./annotations/Monitors/ 5_2___Repair_LCD_Monitors___Replacing_Bad_Capacitors 3
# 204 ./annotations/Monitors/ 5_3___Repair_LCD_Monitors___Replacing_the_Backlight 51
# 205 ./annotations/Monitors/ 6_1___Connect_Two_Monitors___On_Windows 85
# 206 ./annotations/Monitors/ 6_2___Connect_Two_Monitors___Mac_OS_X 32
# 207 ./annotations/Monitors/ 7_1___Use_Your_TV_As_a_Computer_Monitor___Windows 0
# 208 ./annotations/Monitors/ 7_2___Use_Your_TV_As_a_Computer_Monitor___Mac 99
# 209 ./annotations/Monitors/ 8_1___Fix_a_Scratch_on_an_LCD_Screen___Using_a_Professional_Scratch_Repair_Kit 32
# 210 ./annotations/Monitors/ 8_2___Fix_a_Scratch_on_an_LCD_Screen___Purchasing_a_New_LCD_Screen_Cover 12
# 211 ./annotations/Monitors/ 9_1___Calibrate_Your_Monitor___Preparing_to_Calibrate 30
# 212 ./annotations/Monitors/ 9_2___Calibrate_Your_Monitor___Calibrating_on_Windows 33
# 213 ./annotations/Monitors/ 9_3___Calibrate_Your_Monitor___Calibrating_on_Mac 91
# 214 ./annotations/Monitors/ 9_4___Calibrate_Your_Monitor___Using_a_Colorimeter 79
# 215 ./annotations/OS/ 223_1___Open_EXE_Files___ 89
# 216 ./annotations/OS/ 223_2___Open_EXE_Files___ 56
# 217 ./annotations/OS/ 224_1___Format_a_PC___Formatting_Your_Primary_Drive 37
# 218 ./annotations/OS/ 224_2___Format_a_PC___Formatting_a_Secondary_Drive 2
# 219 ./annotations/OS/ 224_3___Format_a_PC___Shrinking_an_Existing_Drive 98
# 220 ./annotations/OS/ 224_4___Format_a_PC___Securely_Formatting_a_Drive 30
# 221 ./annotations/OS/ 225_1___Install_an_Operating_System_on_a_Brand_New_Computer___On_Windows 46
# 222 ./annotations/OS/ 225_2___Install_an_Operating_System_on_a_Brand_New_Computer___On_Mac 37
# 223 ./annotations/OS/ 226_1___Install_a_New_Operating_System_on_Your_Computer___Determining_Which_Operating_System_to_Install 12
# 224 ./annotations/OS/ 226_2___Install_a_New_Operating_System_on_Your_Computer___Installing_Your_New_Operating_System 98
# 225 ./annotations/OS/ 226_3___Install_a_New_Operating_System_on_Your_Computer___Installing_Specific_Operating_Systems 19
# 226 ./annotations/OS/ 227_1___Make_a_Computer_Operating_System___Learning_the_Basics 20
# 227 ./annotations/OS/ 227_2___Make_a_Computer_Operating_System___Building_Your_Operating_System 58
# 228 ./annotations/OS/ 228_1___Find_System_Specs___Windows 74
# 229 ./annotations/OS/ 228_2___Find_System_Specs___Linux 14
# 230 ./annotations/OS/ 229_1___Use_an_Operating_System_from_a_USB_Stick___Creating_a_Windows_or_Linux_Bootable_Drive_with_Rufus 51
# 231 ./annotations/OS/ 229_2___Use_an_Operating_System_from_a_USB_Stick___ 42
# 232 ./annotations/OS/ 230_1___Install_Chromium_OS___Installing_Chromium_OS_to_a_Computer_Using_CloudReady 87
# 233 ./annotations/OS/ 230_2___Install_Chromium_OS___Running_Chromium_OS_from_a_USB_drive_in_Live_Mode 4
# 234 ./annotations/OS/ 231_1___Lock_Desktop_Icons_in_Place___Using_DeskLock_on_Windows 72
# 235 ./annotations/OS/ 231_2___LockDesktopIconsinPlaceSortingbyTagsonMac 8
# 236 ./annotations/OS/ 232_1___Set_Administrator_Password___Windows 4
# 237 ./annotations/OS/ 232_2___Set_Administrator_Password___OS_X 98
# 238 ./annotations/OS/ 233_1___Install_Two_Operating_Systems_on_One_Computer___Creating_a_Bootable_Drive 28
# 239 ./annotations/OS/ 233_2___Install_Two_Operating_Systems_on_One_Computer___Creating_a_Disk_Partition 83
# 240 ./annotations/OS/ 233_3___Install_Two_Operating_Systems_on_One_Computer___Preparing_Your_Computer 10
# 241 ./annotations/OS/ 233_4___Install_Two_Operating_Systems_on_One_Computer___Installing_a_Second_Operating_System 15
# 242 ./annotations/OS/ 234_1___Exit_out_of_a_Frozen_Computer_Program___ 71
# 243 ./annotations/OS/ 235_1___Enter_Data_in_SPSS___Entering_In_Your_Own_Data 50
# 244 ./annotations/OS/ 236_1___Format_a_Hard_Drive___Using_Windows 64
# 245 ./annotations/OS/ 236_2___Format_a_Hard_Drive___Using_a_Mac 93
# 246 ./annotations/OS/ 237_1___Change_Startup_Programs_on_Your_Computer___On_Windows 7
# 247 ./annotations/OS/ 237_2___Change_Startup_Programs_on_Your_Computer___On_Mac 74
# 248 ./annotations/OS/ 238_1___Use_Keyboard_Shortcuts___Windows 7
# 249 ./annotations/OS/ 238_2___Use_Keyboard_Shortcuts___Mac 83
# 250 ./annotations/OS/ 239_1___Print_a_List_of_Files___Using_Windows 67
# 251 ./annotations/OS/ 240_1___Remove_Unwanted_Programs_from_Your_Computer___Steps 10
# 252 ./annotations/OS/ 241_1___Use_MS_DOS___Steps 82
# 253 ./annotations/OS/ 242_1___Disconnect_a_Mapped_Network_Drive___On_Windows 85
# 254 ./annotations/OSX/ 1145_1___Take_a_Screenshot_on_a_Mac___Screenshot_a_Portion_of_Your_Screen 61
# 255 ./annotations/OSX/ 1146_1___Install_macOS_on_a_Windows_PC___Preparing_to_Install 91
# 256 ./annotations/OSX/ 1146_2___Install_macOS_on_a_Windows_PC___Downloading_Unibeast 64
# 257 ./annotations/OSX/ 1146_3___Install_macOS_on_a_Windows_PC___Downloading_the_macOS_High_Sierra_Installer 84
# 258 ./annotations/OSX/ 1146_4___Install_macOS_on_a_Windows_PC___Formatting_Your_USB_Drive 17
# 259 ./annotations/OSX/ 1146_5___Install_macOS_on_a_Windows_PC___Creating_the_Unibeast_Installation_Tool 43
# 260 ./annotations/OSX/ 1146_6___Install_macOS_on_a_Windows_PC___Changing_Windows_Boot_Order 12
# 261 ./annotations/OSX/ 1146_7___Install_macOS_on_a_Windows_PC___Installing_macOS_on_Your_PC 9
# 262 ./annotations/OSX/ 1146_8___Install_macOS_on_a_Windows_PC___Enabling_Drivers_with_Multibeast 33
# 263 ./annotations/OSX/ 1147_1___Download_YouTube_Videos_on_a_Mac___Using_QuickTime 57
# 264 ./annotations/OSX/ 1147_2___Download_YouTube_Videos_on_a_Mac___Using_VLC_Media_Player 0
# 265 ./annotations/OSX/ 1147_3___Download_YouTube_Videos_on_a_Mac___Using_ClipGrab 32
# 266 ./annotations/OSX/ 1148_1___Open_RAR_Files_on_Mac_OS_X___Using_Unarchiver 91
# 267 ./annotations/OSX/ 1148_2___Open_RAR_Files_on_Mac_OS_X___Using_StuffIt_Expander 0
# 268 ./annotations/OSX/ 1149_1___Clear_the_Cache_on_a_Mac___Clearing_the_System_Cache 89
# 269 ./annotations/OSX/ 1149_2___Clear_the_Cache_on_a_Mac___Clearing_the_Safari_Cache 57
# 270 ./annotations/OSX/ 1150_1___Add_a_Customised_Background_on_Photo_Booth_Mac___Steps 22
# 271 ./annotations/OSX/ 1151_1___Reset_a_Lost_Admin_Password_on_Mac_OS_X___Using_Recovery_Mode 46
# 272 ./annotations/OSX/ 1151_2___Reset_a_Lost_Admin_Password_on_Mac_OS_X___Using_Your_Apple_ID 48
# 273 ./annotations/OSX/ 1151_3___Reset_a_Lost_Admin_Password_on_Mac_OS_X___Using_a_Different_Admin_Account 70
# 274 ./annotations/OSX/ 1151_4___Reset_a_Lost_Admin_Password_on_Mac_OS_X___Changing_Your_Password_if_You_Know_It 83
# 275 ./annotations/OSX/ 1152_1___Show_Hidden_Files_and_Folders_on_a_Mac___Showing_Hidden_Files 27
# 276 ./annotations/OSX/ 1152_2___Show_Hidden_Files_and_Folders_on_a_Mac___Making_Hidden_Files_Visible 94
# 277 ./annotations/OSX/ 1153_1___Resize_Pictures_for_Macs___Resizing_an_Image_in_Preview 45
# 278 ./annotations/OSX/ 1153_2___Resize_Pictures_for_Macs___Cropping_an_Image_in_Preview 97
# 279 ./annotations/OSX/ 1154_1___Stop_an_Application_from_Opening_at_Startup_With_Mac_OS_X___Steps 23
# 280 ./annotations/Printers/ 18_1___Scan_a_Document_on_a_Canon_Printer___Preparing_to_Scan 52
# 281 ./annotations/Printers/ 18_2___Scan_a_Document_on_a_Canon_Printer___Scanning_on_Windows 69
# 282 ./annotations/Printers/ 18_3___Scan_a_Document_on_a_Canon_Printer___Scanning_on_Mac 74
# 283 ./annotations/Printers/ 19_1___Set_up_Your_Laptop_to_Print_Wirelessly___Sharing_a_Printer_Between_Windows_Computers 91
# 284 ./annotations/Printers/ 19_2___Set_up_Your_Laptop_to_Print_Wirelessly___Sharing_a_Printer_Between_Mac_Computers 98
# 285 ./annotations/Printers/ 20_1___Install_a_Network_Printer___Installing_a_Standalone_Printer 91
# 286 ./annotations/Printers/ 20_2___Install_a_Network_Printer___Sharing_a_Windows_Printer 68
# 287 ./annotations/Printers/ 20_3___Install_a_Network_Printer___Sharing_a_Mac_Printer 40
# 288 ./annotations/Printers/ 20_4___Install_a_Network_Printer___Installing_a_Network_Printer_via_IP_Address 15
# 289 ./annotations/Printers/ 21_2___Set_Up_a_Wireless_Printer_Connection___Printing_from_an_Android 73
# 290 ./annotations/Printers/ 21_3___Set_Up_a_Wireless_Printer_Connection___Printing_from_an_iPhone_or_iPad 37
# 291 ./annotations/Printers/ 22_1___Fix_a_Print_Spooler___Changing_Print_Spooler_Properties 85
# 292 ./annotations/Printers/ 22_2___Fix_a_Print_Spooler___Restoring_Default_Printer_State 32
# 293 ./annotations/Printers/ 22_3___Fix_a_Print_Spooler___Scanning_System_Files 87
# 294 ./annotations/Printers/ 23_1___Connect_a_Printer_to_Your_Computer___Connecting_a_Wired_Printer_on_Windows 25
# 295 ./annotations/Printers/ 23_2___Connect_a_Printer_to_Your_Computer___Connecting_a_Wired_Printer_on_Mac 13
# 296 ./annotations/Printers/ 23_3___Connect_a_Printer_to_Your_Computer___Connecting_a_Wireless_Printer_on_Windows 41
# 297 ./annotations/Printers/ 23_4___Connect_a_Printer_to_Your_Computer___Connecting_a_Wireless_Printer_on_Mac 93
# 298 ./annotations/Printers/ 23_6___Connect_a_Printer_to_Your_Computer___Sharing_a_Printer_to_a_Network_on_Mac 30
# 299 ./annotations/Printers/ 24_1___Install_a_Printer_Without_the_Installation_Disk___Using_a_USB_Cable_on_Windows 7
# 300 ./annotations/Printers/ 24_2___Install_a_Printer_Without_the_Installation_Disk___Using_a_USB_Cable_on_Mac 93
# 301 ./annotations/Printers/ 24_3___Install_a_Printer_Without_the_Installation_Disk___Downloading_Software 74
# 302 ./annotations/Printers/ 25_1___Connect_the_HP_Deskjet_3050_to_a_Wireless_Router___Windows_8 6
# 303 ./annotations/Printers/ 25_2___Connect_the_HP_Deskjet_3050_to_a_Wireless_Router___ 76
# 304 ./annotations/Printers/ 25_4___Connect_the_HP_Deskjet_3050_to_a_Wireless_Router___Mac_OS_X_v10.8_and_Earlier_Versions 66
# 305 ./annotations/Printers/ 26_1___Add_an_HP_Printer_to_a_Wireless_Network___Connecting_Automatically 2
# 306 ./annotations/Printers/ 26_2___Add_an_HP_Printer_to_a_Wireless_Network___Connecting_Manually 84
# 307 ./annotations/Printers/ 27_1___Clean_Print_Heads___Using_Self-Cleaning_on_Windows 65
# 308 ./annotations/Printers/ 27_2___Clean_Print_Heads___Using_Self-Cleaning_on_Mac 59
# 309 ./annotations/Printers/ 27_3___Clean_Print_Heads___Using_Manual_Cleaning 7
# 310 ./annotations/Printers/ 28_1___Print_Double_Sided___On_PC 70
# 311 ./annotations/Printers/ 28_2___Print_Double_Sided___On_Mac 44
# 312 ./annotations/Printers/ 28_3___Print_Double_Sided___Printing_Double-Sided_Manually 85
# 313 ./annotations/Printers/ 29_3___Stop_Printer_Spooling_on_a_Windows_Computer___Using_the_Task_Manager 14
# 314 ./annotations/Printers/ 30_1___Align_Your_HP_Printer___Using_HP_Smart_for_Windows_10 4
# 315 ./annotations/Printers/ 30_2___Align_Your_HP_Printer___Using_HP_Solutions_Center_or_Printer_Assistant_for_Windows 63
# 316 ./annotations/Printers/ 30_3___Align_Your_HP_Printer___Using_HP_Utility_on_a_Mac 11
# 317 ./annotations/Printers/ 30_4___Align_Your_HP_Printer___ 27
# 318 ./annotations/Printers/ 31_1___Install_Canon_Wireless_Printer___Installing_on_Windows 15
# 319 ./annotations/Printers/ 31_2___Install_Canon_Wireless_Printer___On_Mac 58
# 320 ./annotations/Printers/ 33_1___Activate_Airprint___Windows 42
# 321 ./annotations/Printers/ 33_2___Activate_Airprint___OS_X 48
# 322 ./annotations/Printers/ 34_1___Print_in_Black_and_White_on_Epson_Printers___Changing_Default_Settings_on_Windows 10
# 323 ./annotations/Printers/ 34_2___Print_in_Black_and_White_on_Epson_Printers___Changing_Default_Settings_on_Mac 36
# 324 ./annotations/Printers/ 34_3___Print_in_Black_and_White_on_Epson_Printers___Printing_in_Black_and_White_Manually 32
# 325 ./annotations/Printers/ 35_1___Find_Your_Printer_IP_Address___Finding_Your_Printer_IP_on_Windows 68
# 326 ./annotations/Printers/ 36_1___Connect_Printer_to_iPad___Connecting_to_AirPrint 20
# 327 ./annotations/Printers/ 36_2___Connect_Printer_to_iPad___Printing_with_AirPrint 48
# 328 ./annotations/Printers/ 37_1___3D_Print_with_CURA_on_Creality%27s_Ender_3___Using_CURA 0
# 329 ./annotations/Printers/ 37_2___3D_Print_with_CURA_on_Creality%27s_Ender_3___Loading_the_Filament 85
# 330 ./annotations/Printers/ 37_3___3D_Print_with_CURA_on_Creality%27s_Ender_3___Printing_the_Object 74
# 331 ./annotations/Printers/ 38_1___Put_Ink_Cartridges_in_a_Printer___Putting_Ink_Cartridges_in_a_HP_Printer 3
# 332 ./annotations/Printers/ 38_3___Put_Ink_Cartridges_in_a_Printer___Putting_Ink_Cartridges_in_an_Epson_Printer 40
# 333 ./annotations/Printers/ 39_1___Reset_an_HP_Photosmart_Printer___Resetting_the_Printer 48
# 334 ./annotations/Printers/ 40_1___Replace_a_Toner_Cartridge_in_a_Laser_Printer___Steps 75
# 335 ./annotations/Scanners/ 185_1___Scan_Documents_Into_PDF___On_Windows 85
# 336 ./annotations/Scanners/ 185_2___Scan_Documents_Into_PDF___On_Mac 71
# 337 ./annotations/Scanners/ 185_3___Scan_Documents_Into_PDF___Converting_a_Scan_Image_File_into_a_PDF 28
# 338 ./annotations/Scanners/ 186_1___Email_a_Scanned_Document___Steps 88
# 339 ./annotations/Scanners/ 187_1___Scan_Photos___Scanning_the_Image 4
# 340 ./annotations/Scanners/ 187_2___Scan_Photos___Scanning_Like_a_Pro 67
# 341 ./annotations/Scanners/ 188_1___Scan_Multiple_Pages_Into_One_PDF_File___Using_A_Computer_and_Scanner 17
# 342 ./annotations/Scanners/ 188_2___Scan_Multiple_Pages_Into_One_PDF_File___Using_a_Mobile_App 75
# 343 ./annotations/Scanners/ 189_1___Scan_a_Book___ 74
# 344 ./annotations/Scanners/ 189_2___Scan_a_Book___Scanning_by_Speed-Reading 84
# 345 ./annotations/Scanners/ 190_1___Transfer_a_Hand_Drawing_to_a_Computer___Using_a_Scanner 46
# 346 ./annotations/Scanners/ 190_2___Transfer_a_Hand_Drawing_to_a_Computer___Taking_a_Photo 78
# 347 ./annotations/Scanners/ 191_1___Scan_and_Print_Pictures_from_a_Computer___Scanning 5
# 348 ./annotations/Scanners/ 191_2___Scan_and_Print_Pictures_from_a_Computer___Printing 73
# 349 ./annotations/Scanners/ 192_1___Add_a_Scanner_to_Image_Capture___Steps 2
# 350 ./annotations/Scanners/ 193_1___Choose_a_Photo_Scanner___Steps 51
# 351 ./annotations/Scanners/ 194_1___Network_a_Scanner___Connecting_a_Scanner_to_a_Networked_Computer_Using_Mac_OS_X 25
# 352 ./annotations/Scanners/ 195_1___Clean_a_Biometric_Scanner___Steps 0
# 353 ./annotations/Scanners/ 196_1___Scan_a_Document_with_an_HP_Deskjet_5525_Directly_to_Your_Memory_Card___Scanning_to_Your_Memory_Card 58
# 354 ./annotations/Scanners/ 197_1___Prepare_Paperwork_for_Scanning___Steps 82
# 355 ./annotations/Scanners/ 198_1___Pick_a_Great_Slide_and_Photo_Scanner___Steps 33
# 356 ./annotations/Ubuntu/ 646_1___Uninstall_Ubuntu_Software___Uninstalling_Programs_with_Terminal 88
# 357 ./annotations/Ubuntu/ 646_2___Uninstall_Ubuntu_Software___Uninstalling_Programs_with_Ubuntu_Software 97
# 358 ./annotations/Ubuntu/ 646_3___Uninstall_Ubuntu_Software___Uninstalling_Ubuntu_Linux 81
# 359 ./annotations/Ubuntu/ 647_1___Install_Ubuntu_on_VirtualBox___Downloading_Ubuntu 12
# 360 ./annotations/Ubuntu/ 647_2___Install_Ubuntu_on_VirtualBox___Creating_a_Virtual_Machine 73
# 361 ./annotations/Ubuntu/ 647_3___Install_Ubuntu_on_VirtualBox___Installing_Ubuntu 96
# 362 ./annotations/Ubuntu/ 647_4___Install_Ubuntu_on_VirtualBox___Setting_up_Ubuntu 47
# 363 ./annotations/Ubuntu/ 648_1___Format_a_Hard_Drive_Using_Ubuntu___Performing_a_Quick_Format 4
# 364 ./annotations/Ubuntu/ 648_2___Format_a_Hard_Drive_Using_Ubuntu___Using_GParted 82
# 365 ./annotations/Ubuntu/ 649_1___Install_Windows_from_Ubuntu___Creating_a_Primary_NTFS_Partition_for_Windows 80
# 366 ./annotations/Ubuntu/ 649_2___Install_Windows_from_Ubuntu___Creating_a_Windows_10_Install_Drive_in_Ubuntu 99
# 367 ./annotations/Ubuntu/ 649_3___Install_Windows_from_Ubuntu___Running_the_Windows_Installer 85
# 368 ./annotations/Ubuntu/ 649_4___Install_Windows_from_Ubuntu___Setting_Up_Dual_Boot 55
# 369 ./annotations/Ubuntu/ 650_1___Format_a_USB_Flash_Drive_in_Ubuntu___Using_the_Disks_Utility 93
# 370 ./annotations/Ubuntu/ 650_2___Format_a_USB_Flash_Drive_in_Ubuntu___Using_the_Terminal 77
# 371 ./annotations/Ubuntu/ 651_1___Become_Root_in_Ubuntu___Running_Root_Commands_with_Sudo 65
# 372 ./annotations/Ubuntu/ 651_2___Become_Root_in_Ubuntu___Enabling_the_Root_User 28
# 373 ./annotations/Ubuntu/ 652_1___Install_Ubuntu_Linux___Preparing_to_Install 69
# 374 ./annotations/Ubuntu/ 652_2___Install_Ubuntu_Linux___Installing_on_Windows 74
# 375 ./annotations/Ubuntu/ 652_3___Install_Ubuntu_Linux___Installing_on_Mac 40
# 376 ./annotations/Ubuntu/ 653_1___Change_Keyboard_Layout_in_Ubuntu___Steps 1
# 377 ./annotations/Ubuntu/ 654_1___Set_up_an_FTP_Server_in_Ubuntu_Linux___Installing_the_FTP_Framework 2
# 378 ./annotations/Ubuntu/ 654_2___Set_up_an_FTP_Server_in_Ubuntu_Linux___Configuring_the_FTP_Server 86
# ERROR
# 379 ./annotations/Ubuntu/ 654_3___Set_up_an_FTP_Server_in_Ubuntu_Linux___Adding_Usernames_to_the_CHROOT_List 8
# 380 ./annotations/Ubuntu/ 654_4___Set_up_an_FTP_Server_in_Ubuntu_Linux___Accessing_Your_Server 30
# 381 ./annotations/Ubuntu/ 655_1___Install_Flash_Player_on_Ubuntu___Chromium 14
# 382 ./annotations/Ubuntu/ 655_2___Install_Flash_Player_on_Ubuntu___Firefox 62
# 383 ./annotations/Ubuntu/ 656_1___Enable_the_Windows_Subsystem_for_Linux___Checking_Your_Computer_for_Compatibility 93
# 384 ./annotations/Ubuntu/ 656_2___Enable_the_Windows_Subsystem_for_Linux___Enabling_Developer_Mode 17
# 385 ./annotations/Ubuntu/ 656_3___Enable_the_Windows_Subsystem_for_Linux___Turning_on_Windows_Subsystem_for_Linux 70
# 386 ./annotations/Ubuntu/ 657_1___Set_up_a_Network_in_Ubuntu___Steps 49
# 387 ./annotations/Ubuntu/ 658_1___Set_Up_Your_Java_Home_Path_in_Ubuntu___Steps 37
# 388 ./annotations/Ubuntu/ 659_1___Change_Themes_on_Ubuntu_with_Gnome_Tweak_Tool___Installing_GNOME_Tweak_Tool_and_Shell_Extensions 40
# 389 ./annotations/Ubuntu/ 659_2___Change_Themes_on_Ubuntu_with_Gnome_Tweak_Tool___Acquiring_GNOME_Shell_Themes 71
# 390 ./annotations/Ubuntu/ 659_3___Change_Themes_on_Ubuntu_with_Gnome_Tweak_Tool___Setting_Themes_with_GNOME_Tweak_Tool 53
# 391 ./annotations/Ubuntu/ 660_1___Install_Gnome_on_Ubuntu___Steps 12
# 392 ./annotations/Ubuntu/ 661_1___Install_Software_in_Ubuntu___Installing_Graphically 29
# 393 ./annotations/Ubuntu/ 662_1___Install_JavaFX_on_Ubuntu_Linux___Steps 31
# 394 ./annotations/Ubuntu/ 663_1___Install_Windows_Programs_in_Ubuntu___Steps 49
# 395 ./annotations/Ubuntu/ 664_1___Install_WhatsApp_on_Ubuntu___Steps 67
# 396 ./annotations/Ubuntu/ 665_1___Install_Skype_in_Ubuntu___Installing_Skype_Snap 90
# 397 ./annotations/Ubuntu/ 665_2___Install_Skype_in_Ubuntu___Install_Skype_Snap_in_a_Terminal 31
# 398 ./annotations/Ubuntu/ 665_3___Install_Skype_in_Ubuntu___Installing_Legacy_Skype 85
# 399 ./annotations/Ubuntu/ 665_4___Install_Skype_in_Ubuntu___Running_Skype 75
# 400 ./annotations/Webcams/ 205_1___Set_up_a_Webcam___Installing_the_Webcam 55
# 401 ./annotations/Webcams/ 205_2___Set_up_a_Webcam___Setting_up_the_Webcam 34
# 402 ./annotations/Webcams/ 206_1___Install_a_Logitech_Webcam___Downloading_Software_and_Drivers 51
# 403 ./annotations/Webcams/ 207_1___Fix_a_Webcam_That_Is_Displaying_a_Black_Screen_on_Windows___General_Fixes 98
# 404 ./annotations/Webcams/ 207_2___Fix_a_Webcam_That_Is_Displaying_a_Black_Screen_on_Windows___Using_Device_Manager 59
# 405 ./annotations/Webcams/ 208_1___Use_a_Digital_Camera_As_a_Web_Cam___Steps 48
# 406 ./annotations/Webcams/ 209_1___Record_a_Video_on_PC__Steps 75
# 407 ./annotations/Webcams/ 210_1___Buy_a_Webcam___Steps 25
# 408 ./annotations/Webcams/ 211_1___Improve_Your_Webcam%27s_Output_Quality___Steps 35
# 409 ./annotations/Webcams/ 212_1___Stream_Your_Webcam___Encoding_a_Stream_with_OBS_Studio 26
# 410 ./annotations/Webcams/ 212_2___Stream_Your_Webcam___Streaming_Directly_from_Your_Webcam_on_YouTube 11
# 411 ./annotations/Webcams/ 212_3___Stream_Your_Webcam___Streaming_Directly_from_Your_Webcam_on_Facebook 2
# 412 ./annotations/Webcams/ 213_1___Webcam_With_Another_Person___Using_a_Webcam_with_Skype 15
# 413 ./annotations/Webcams/ 214_1___Add_a_Webcam_to_OBS_on_PC_or_Mac___Steps 88
# 414 ./annotations/Webcams/ 215_1___Choose_a_Site_to_Webcam_Model_For___Steps 39
# 415 ./annotations/Webcams/ 216_1___Make_a_Webcam_Into_an_Infrared_Camera___Steps 1
# 416 ./annotations/Webcams/ 217_1___Use_Webcam_on_Windows_Movie_Maker___Choosing_the_Webcam 27
# 417 ./annotations/Webcams/ 218_1___Protect_Your_Webcam_from_Being_Hacked___ 96
# 418 ./annotations/Webcams/ 218_2___Protect_Your_Webcam_from_Being_Hacked___ 12
# 419 ./annotations/Webcams/ 219_1___Approach_a_Webcam_Job_Interview___Steps 67
# 420 ./annotations/Webcams/ 220_1___Make_a_Webcam_Stand_out_of_a_Coke_Can___The_Stand 14
# 421 ./annotations/Webcams/ 220_2___Make_a_Webcam_Stand_out_of_a_Coke_Can___The_Blocker 81
# 422 ./annotations/Webcams/ 221_1___Use_a_Web_Camera___Using_Windows 25
# 423 ./annotations/Webcams/ 221_2___Use_a_Web_Camera___Using_Mac 84
# 424 ./annotations/Webcams/ 222_1___Use_an_iSight_Webcam___External_iSight_Method 96
# 425 ./annotations/Windows/ 265_1___Take_a_Screenshot_in_Microsoft_Windows___Taking_a_FullScreen_Screenshot_on_Any_Windows_Computer 70
# 426 ./annotations/Windows/ 265_2___Take_a_Screenshot_in_Microsoft_Windows___Taking_a_OneWindow_Screenshot 1
# 427 ./annotations/Windows/ 265_3___Take_a_Screenshot_in_Microsoft_Windows___Using_the_Snipping_Tool_Program 93
# 428 ./annotations/Windows/ 265_4___Take_a_Screenshot_in_Microsoft_Windows___Using_the_Snipping_Tool_Shortcut 50
# 429 ./annotations/Windows/ 265_5___Take_a_Screenshot_in_Microsoft_Windows___Screenshotting_Several_Windows_in_a_Row 25
# 430 ./annotations/Windows/ 266_1___Zoom_in_on_a_PC___Zooming_on_the_Whole_Screen_with_Magnifier 15
# 431 ./annotations/Windows/ 266_2___Zoom_in_on_a_PC___Using_Web_Browser_Zoom_Features 56
# 432 ./annotations/Windows/ 267_1___Create_a_Windows_Icon___Creating_an_Icon_in_ICO_Convert 38
# 433 ./annotations/Windows/ 267_2___Create_a_Windows_Icon___Creating_an_Icon_in_Paint 5
# 434 ./annotations/Windows/ 267_3___Create_a_Windows_Icon___Applying_the_Icon_to_a_Shortcut 39
# 435 ./annotations/Windows/ 268_1___Install_FFmpeg_on_Windows___Downloading_FFmpeg 71
# 436 ./annotations/Windows/ 268_2___Install_FFmpeg_on_Windows___Enabling_FFmpeg_in_the_Command_Line 64
# 437 ./annotations/Windows/ 269_1___Resolve_No_Sound_on_Windows_Computer___Checking_the_Volume 75
# 438 ./annotations/Windows/ 269_2___Resolve_No_Sound_on_Windows_Computer___Running_the_Audio_Troubleshooter 45
# 439 ./annotations/Windows/ 269_3___Resolve_No_Sound_on_Windows_Computer___Disabling_Audio_Enhancements 7
# 440 ./annotations/Windows/ 269_4___Resolve_No_Sound_on_Windows_Computer___Adjusting_the_Speaker_Properties 95
# 441 ./annotations/Windows/ 269_5__ResolveNoSoundonWindowsComputerUpdatingtheSoundDrivers 29
# 442 ./annotations/Windows/ 270_1___Check_Your_Windows_Product_Key___Using_Command_Prompt 31
# 443 ./annotations/Windows/ 270_2___Check_Your_Windows_Product_Key___Using_ProduKey 22
# 444 ./annotations/Windows/ 270_3___Check_Your_Windows_Product_Key___ 69
# 445 ./annotations/Windows/ 271_1___Change_or_Create_Desktop_Icons_for_Windows___Changing_System_Desktop_Icons 81
# 446 ./annotations/Windows/ 271_2___Change_or_Create_Desktop_Icons_for_Windows___Changing_Shortcut_and_Folder_Icons 61
# 447 ./annotations/Windows/ 271_3___Change_or_Create_Desktop_Icons_for_Windows___Downloading_Icons 88
# 448 ./annotations/Windows/ 271_4___Change_or_Create_Desktop_Icons_for_Windows___Creating_Icons 80
# 449 ./annotations/Windows/ 271_5___Change_or_Create_Desktop_Icons_for_Windows___Adding_Shortcuts_to_the_Desktop 75
# 450 ./annotations/Windows/ 271_6___Change_or_Create_Desktop_Icons_for_Windows___Removing_Arrows_from_Shortcut_Icons 22
# 451 ./annotations/Windows/ 272_1___Hide_the_Windows_Taskbar___Windows_10 51
# 452 ./annotations/Windows/ 272_2___Hide_the_Windows_Taskbar___Troubleshooting 33
# 453 ./annotations/Windows/ 272_3___Hide_the_Windows_Taskbar___Troubleshooting_Windows_10 22
# 454 ./annotations/Windows/ 273_1___Block_a_Program_with_Windows_Firewall___Blocking_a_Program 92
# 455 ./annotations/Windows/ 273_2___Block_a_Program_with_Windows_Firewall___Temporarily_Disabling_a_Program 94
# 456 ./annotations/Windows/ 274_1__FindaUsersSIDonWindowsSteps 57
# 457 ./annotations/Windows/ 275_1___See_Active_Network_Connections_Windows___Accessing_the_Network_and_Sharing_Menu_in_Windows_7_through_10 45
# 458 ./annotations/Windows/ 275_2___See_Active_Network_Connections_Windows___Using_the_Network_Connections_Folder_in_Windows_7 38
# 459 ./annotations/Windows/ 275_3___See_Active_Network_Connections_Windows___Using_the_Netstat_Command_in_Vista_or_Later 78
# 460 ./annotations/Windows/ 275_4___See_Active_Network_Connections_Windows___Using_the_Netstat_Command_in_XP 47
# 461 ./annotations/Windows/ 276_1___Check_Your_Windows_Version___Find_Your_Windows_Version_in_Settings 72
# 462 ./annotations/Windows/ 277_1___Turn_Off_Windows_Activation___Using_Services 90
# 463 ./annotations/Windows/ 277_2___Turn_Off_Windows_Activation___Using_Registry_Editor 59
# 464 ./annotations/Windows/ 277_3___Turn_Off_Windows_Activation___Activating_Windows 57
# 465 ./annotations/Windows/ 278_1___Change_Process_Priorities_in_Windows_Task_Manager___Steps 0
# ERROR
# 466 ./annotations/Windows/ 279_1___Install_Windows_from_Ubuntu___Creating_a_Primary_NTFS_Partition_for_Windows 44
# 467 ./annotations/Windows/ 279_2___Install_Windows_from_Ubuntu___Creating_a_Windows_10_Install_Drive_in_Ubuntu 89
# 468 ./annotations/Windows/ 279_3___Install_Windows_from_Ubuntu___Running_the_Windows_Installer 74
# 469 ./annotations/Windows/ 279_4___Install_Windows_from_Ubuntu___Setting_Up_Dual_Boot 7
# 470 ./annotations/Windows/ 280_1___Increase_Dedicated_Video_RAM_on_Windows_Laptops_with_Intel_Graphics___Checking_Your_Video_RAM 5
# 471 ./annotations/Windows/ 280_2__IncreaseDedicatedVideoRAMonWindowsLaptopswithIntelGraphicsUsingtheRegistryEditor 77
# 472 ./annotations/Windows/ 281_1___Create_a_JARVIS_Like_AI_Assistant___Steps 51
# 473 ./annotations/Windows/ 282_1___Recover_Deleted_History_in_Windows___Downloading_Recovery_Software 97
# 474 ./annotations/Windows/ 283_1___Format_a_Dell_Computer___Using_Windows_Reset 21
# 475 ./annotations/Windows/ 283_2___Format_a_Dell_Computer___Using_the_Dell_Computer_Repair_Drive 9
# 476 ./annotations/Windows/ 283_3___Format_a_Dell_Computer___Using_a_Windows_Installation_Disc 22
# 477 ./annotations/Windows/ 284_1___Enter_BIOS___Using_Windows_10 59
# 478 ./annotations/Windows/ 284_2___Enter_BIOS___Using_Windows_8_and_81 69
# 479 ./annotations/Windows10/ 731_1___Turn_Off_Windows_Defender_in_Windows_10___Turning_Off_Windows_Defender 68
# 480 ./annotations/Windows10/ 731_2___Turn_Off_Windows_Defender_in_Windows_10___Disabling_Windows_Defender 14
# 481 ./annotations/Windows10/ 732_1___Install_Windows_10___Booting_to_the_Windows_10_Installer 71
# 482 ./annotations/Windows10/ 732_2___Install_Windows_10___Installing 0
# 483 ./annotations/Windows10/ 733_1___Enable_Image_Preview_to_Display_Pictures_in_a_Folder_Windows_10___Enabling_Image_Previews 27
# 484 ./annotations/Windows10/ 733_2___Enable_Image_Preview_to_Display_Pictures_in_a_Folder_Windows_10___Fixing_Corrupted_Previews 62
# 485 ./annotations/Windows10/ 734_1___Delete_a_User_Account_Picture_in_Windows_10___Reverting_to_the_Default_User_Photo 63
# 486 ./annotations/Windows10/ 734_2___Delete_a_User_Account_Picture_in_Windows_10___Removing_a_Profile_Photo_from_a_Microsoft_Account 12
# 487 ./annotations/Windows10/ 735_1___Set_Up_a_Second_Monitor_with_Windows_10___Steps 28
# 488 ./annotations/Windows10/ 736_1___Enable_Active_Directory_in_Windows_10___Installing_Remote_Server_Administration_Tools 48
# 489 ./annotations/Windows10/ 736_2___EnableActiveDirectoryinWindows10EnablingActiveDirectory 83
# 490 ./annotations/Windows10/ 737_1___LoginAsanAdministratorinWindows10Steps 39
# 491 ./annotations/Windows10/ 738_1___Fix_Microsoft_Store_Downloading_Problems___ 34
# 492 ./annotations/Windows10/ 738_2___Fix_Microsoft_Store_Downloading_Problems___Updating_Your_Current_Apps 43
# 493 ./annotations/Windows10/ 738_3___Fix_Microsoft_Store_Downloading_Problems___Signing_Out_of_the_Microsoft_Store 44
# 494 ./annotations/Windows10/ 738_4___Fix_Microsoft_Store_Downloading_Problems___ 65
# 495 ./annotations/Windows10/ 739_1___Eject_the_CD_Tray_for_Windows_10___Using_Windows 48
# 496 ./annotations/Windows10/ 739_2___Eject_the_CD_Tray_for_Windows_10___Using_a_Paperclip_if_the_Drive_is_Stuck 40
# 497 ./annotations/Windows10/ 739_3___Eject_the_CD_Tray_for_Windows_10___Ejecting_from_Inside_a_Desktop_PC 50
# 498 ./annotations/Windows10/ 740_1___Screenshot_in_Windows_10___ 96
# 499 ./annotations/Windows10/ 740_2___Screenshot_in_Windows_10___Using_PrtSc_Key_to_Capture_One_Window 23
# 500 ./annotations/Windows10/ 740_3___Screenshot_in_Windows_10___Using_the_Snipping_Tool 20
# 501 ./annotations/Windows10/ 741_1___Clear_Temp_Files_in_Windows_10___Using_Settings 21
# 502 ./annotations/Windows10/ 742_1___Remove_a_Flash_Drive_from_a_Windows_10_Computer___Using_the_Desktop_Taskbar 75
# 503 ./annotations/Windows10/ 742_2___Remove_a_Flash_Drive_from_a_Windows_10_Computer___Using_the_This_PC_Program 40
# 504 ./annotations/Windows10/ 742_3___Remove_a_Flash_Drive_from_a_Windows_10_Computer___Enabling_Quick_Removal 77
# 505 ./annotations/Windows10/ 743_1___Create_a_Hotspot_in_Windows_10___Steps 74
# 506 ./annotations/Windows10/ 744_1___Close_Apps_in_Windows_10___ 95
# 507 ./annotations/Windows10/ 744_2___Close_Apps_in_Windows_10___Closing_Apps_in_Tablet_Mode 66
# 508 ./annotations/Windows10/ 745_1___Get_Minecraft_Windows_10_Edition___Steps 34
# 509 ./annotations/Windows10/ 746_1___Enable_the_Windows_Subsystem_for_Linux___Checking_Your_Computer_for_Compatibility 20
# 510 ./annotations/Windows10/ 746_2___Enable_the_Windows_Subsystem_for_Linux___Enabling_Developer_Mode 78
# 511 ./annotations/Windows10/ 746_3___Enable_the_Windows_Subsystem_for_Linux___Turning_on_Windows_Subsystem_for_Linux 63
# 512 ./annotations/Windows10/ 747_1___Pin_a_Program_to_the_Windows_10_Taskbar___Pinning_a_Program_to_the_Taskbar_from_the_Start_Menu 99
# 513 ./annotations/Windows10/ 748_1___Record_Your_Screen_in_Windows_10___Using_the_Xbox_Game_Bar 33
# 514 ./annotations/Windows10/ 748_2___Record_Your_Screen_in_Windows_10___Using_FlashBack_Express_Recorder 10
# 515 ./annotations/Windows10/ 749_1___Change_the_Default_Installation_Location_on_Windows_10___Steps 62
# 516 ./annotations/Windows10/ 750_1___Turn_Off_Automatic_Updates_in_Windows_10___Disabling_the_Update_Service 34
# 517 ./annotations/Windows10/ 750_2___Turn_Off_Automatic_Updates_in_Windows_10___Using_a_Metered_Connection 92
# 518 ./annotations/Windows10/ 750_3___Turn_Off_Automatic_Updates_in_Windows_10___Using_Group_Policy_Editor 20
# 519 ./annotations/Windows10/ 750_4___Turn_Off_Automatic_Updates_in_Windows_10___Disabling_Automatic_Windows_Store_App_Updates 67

# %%
# parse_annotations(open('temp.txt','w',encoding='utf-8'),169,'./annotations/Mac/','1017_1___Customize_Your_Mac_Using_the_Terminal___Using_Terminal_Commands','isOpened')
