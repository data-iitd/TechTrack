# %%
import csv

# %%
from os import listdir
from os.path import isfile, join
import xlsxwriter
from collections import Counter

# %%
mypath = './WikiHow Printer/WikiHowSummary/'
pages = [f[:-4] for f in listdir(mypath) if isfile(join(mypath, f))]
# print(pages)

# %%
import pickle
links = pickle.load(open('./html_links_printer.pkl','rb'))
name_to_link = {}
for link in links:
    name_to_link[link.split('/')[3]] = link

# %%
from flashtext import KeywordProcessor
import nltk
from nltk.corpus import stopwords
from nltk.corpus import brown
from nltk.stem import WordNetLemmatizer 
from nltk.tokenize import word_tokenize, sent_tokenize
lemmatizer = WordNetLemmatizer()

# %%
stop_words = set(stopwords.words('english'))
# verbs = {word for word, pos in brown.tagged_words() if pos.startswith('V')}
verbs = pickle.load(open('./verb_entities.pkl','rb'))

# %%
verbs2 = []
for page1 in pages:
    text = open('./WikiHow Printer/WikiHow/'+ page1 +'.txt',encoding="utf8").read()
    tokenized = sent_tokenize(text)
    for sent in tokenized:
        for i in nltk.pos_tag(word_tokenize(sent)):
            word, pos = i
            if(pos.startswith('V')):
#                 if("printer" in word):
#                     print(sent,i)
                verbs2.append(word)
#     v = [word for word, pos in nltk.pos_tag(word_tokenize(text)) if (pos.startswith('V'))]
#     verbs2.update(v)
verbs2 = Counter(verbs2)

# %%
def text_variations(txt):
    txt = txt.strip()
    var = []
    if('-' in txt):#V-cube_6
        if('_' in txt):
            var.append(txt)
            txt = txt.replace('_',' ')#V-cube 6
        var.append(txt)
        txt = txt.replace('-','_')#V_cube 6
    if(' ' in txt):
        var.append(txt)
        txt = txt.replace(' ','_')#V_cube_6
    if('_' in txt):
        var.append(txt)
        txt = txt.replace('_',' ')#V cube 6
    var.append(txt)
    return var

def ents_to_dict(ents_list):
    ent_dict = {}
    for ent in ents_list:
        ent = ent.strip()
        if '(' in ent:
#             print(ent,end='\t')
            ent = ent.split('(')[0][:-1]
#             print(ent)
        ent = lemmatizer.lemmatize(ent)
        if(len(ent)<4) or ent in stop_words or ent in verbs or verbs2[ent]>2:
            continue
        ent_dict[ent] = text_variations(ent)
    return ent_dict

# %%
te_ents = pickle.load(open('./tecknowbase_entities.pkl','rb'))
te_n_ents = pickle.load(open('./tecknowbase_noisy_entities.pkl','rb'))
db_ents = pickle.load(open('./dbpedia_entities.pkl','rb'))
te_dict = ents_to_dict(te_ents)
te_n_dict = ents_to_dict(te_n_ents)
db_dict = ents_to_dict(db_ents)

# %%
te_proc = KeywordProcessor()
te_proc.add_keywords_from_dict(te_dict)
te_n_proc = KeywordProcessor()
te_n_proc.add_keywords_from_dict(te_n_dict)
db_proc = KeywordProcessor()
db_proc.add_keywords_from_dict(db_dict)

# %%
def find_entities(proc, page,freq=3):
    counts = Counter(proc.extract_keywords(page))
    freq_ents = [x for x in counts if counts[x] >= freq]
    return set(freq_ents)

def find_linewise_entities(proc, page,freq=2):
    steps = page.split('\n\n')[:-2]
    linewise = [set(proc.extract_keywords(step)) for step in steps]
    counts = Counter([ent for line in linewise for ent in line])
    freq_ents = [x for x in counts if counts[x] >= freq]
    return set(freq_ents)

def merge(list1, list2):
    l = list(list1)
    for ent2 in list2:
        to_add = True
        for i,ent1 in enumerate(list1):
            if(ent1 in ent2):
                l[i]=ent2
            elif(ent2 in ent1):
                to_add = False
        if(to_add):
            l.append(ent2)
    return set(l)

# %%
def page_to_steps(page):
    return page.split('\n\n')[:-2]

# %%
workbook = xlsxwriter.Workbook('WikiHow_printer_lines_entities.xlsx')
worksheet = workbook.add_worksheet()

# %%
Head = ['Task Number','Step Number','Task Name','URL','Step Description','Step-Ent-TeKnowBase','Step-Ent-TeKnowBase-Noisy','Step-Ent-DBPedia','Step-Ent-Merged','Step-Ent-Stepwise','Summary','Description','Page-Entities-TeKnowBase','Page-Entities-TeKnowBase-Noisy','Page-Entities-DBPedia','Page-Entities-merged','Page-Entities-Stepwise']
for n,h in enumerate(Head):
    worksheet.write(0,n,h)
n = 0
for m,page in enumerate(pages):
    print(page)
    g = open('./WikiHow Printer/WikiHow/'+page+'.txt','r',encoding='utf8')
    text = g.read()
    g1 = open('./WikiHow Printer/WikiHowSummary/'+page+'.txt',encoding='utf8')
    summary = g1.read()
    page_te_ent = ", ".join(find_entities(te_proc,text))
    page_te_n_ent = ", ".join(find_entities(te_n_proc,text))
    page_db_ent = ", ".join(find_entities(db_proc,text))
    page_merged_ent = ", ".join(merge(find_entities(te_proc,text),find_entities(db_proc,text)))
    page_merged_linewise = ", ".join(merge(find_linewise_entities(te_proc,text),find_linewise_entities(db_proc,text)))
    steps = page_to_steps(text)
    
    for i,step in enumerate(steps):
#     for i in range(1):
#         step = page
        step_te_ent = ", ".join(find_entities(te_proc,step,0))
        step_te_n_ent = ", ".join(find_entities(te_n_proc,step,0))
        step_db_ent = ", ".join(find_entities(db_proc,step,0))
        step_merged_ent = ", ".join(merge(find_entities(te_proc,step,0),find_entities(db_proc,step,0)))
        step_merged_linewise = ", ".join(merge(find_linewise_entities(te_proc,step,0),find_linewise_entities(db_proc,step,0)))
        worksheet.write(n+1,0,m+1)
        worksheet.write(n+1,1,i+1)
        worksheet.write(n+1,2,page)
        worksheet.write(n+1,3,name_to_link[page])
        worksheet.write(n+1,4,step)
        worksheet.write(n+1,5,step_te_ent)
        worksheet.write(n+1,6,step_te_n_ent)
        worksheet.write(n+1,7,step_db_ent)
        worksheet.write(n+1,8,step_merged_ent)
        worksheet.write(n+1,9,step_merged_linewise)
        worksheet.write(n+1,10,summary)
        worksheet.write(n+1,11,text)
        worksheet.write(n+1,12,page_te_ent)
        worksheet.write(n+1,13,page_te_n_ent)
        worksheet.write(n+1,14,page_db_ent)
        worksheet.write(n+1,15,page_merged_ent)
        worksheet.write(n+1,16,page_merged_linewise)
        n+=1
        
    
    if(m%20==0):
        print(n)
# Out:
# 3D-Print-an-Object
# 17
# 3D-Print-with-CURA-on-Creality%27s-Ender-3
# Activate-Airprint
# Add-a-Clone-Printer-for-Black-Only-Draft-Print-Jobs
# Add-a-Laser-Printer-to-a-Home-Network
# Add-a-Laser-Printer-to-an-Office-Network
# Add-a-Local-Printer-in-Linux
# Add-a-Network-Printer-in-Windows-XP
# Add-a-Printer-on-HP-SureSupply-on-iOS
# Add-a-Printer-to-Time-Capsule
# Add-a-Printer
# Add-an-HP-Printer-to-a-Wireless-Network
# Adjust-the-Print-Quality-of-a-Laser-Printer
# Align-Your-HP-Printer
# Buy-a-Printer
# Buy-Cheap-Toner
# Buy-Generic-Toner
# Buy-Recycled-Toner-Cartridges
# Cancel-a-Print-Job-on-PC-or-Mac
# Change-Black-Ink-to-Color-on-a-Dell-940-Printer
# Check-How-Much-Ink-is-Left-in-an-Inkjet-Printer
# 277
# Check-if-Your-Printer-Has-Run-out-of-Ink
# Check-Printer-Ink-Levels-in-Windows
# Choose-a-Printer
# Choose-an-All-in-one-Printer-for-a-Home-Office
# Choose-an-Inkjet-Printer-with-the-Highest-Quality-Photo-Printing
# Choose-Multifunction-Printers
# Clean-a-Brother-Printer
# Clean-a-Laser-Printer
# Clean-a-Printer
# Clean-an-Inkjet-Printer%27s-Print-Head-to-Reduce-Streaking
# Clean-Epson-Printer-Nozzles
# Clean-Print-Heads
# Clean-Printer-Rollers
# Clean-the-Nozzle-on-a-3D-Printer
# Clear-a-Paper-Jam-in-a-Laser-Printer
# Clear-a-Paper-Jam-in-an-All-in-One-Printer
# Clear-a-Paper-Jam-in-an-Epson-Laser-Printer
# Clear-a-Paper-Jam-on-an-HP-Inkjet-Printer
# Clear-a-Paper-Jam
# Clear-a-Printer-Spooler
# 553
# Configure-a-Print-Server
# Connect-a-Printer-to-Your-Computer
# Connect-a-Wireless-Print-Server
# Connect-an-HP-Deskjet-5525-to-Your-Home-Network
# Connect-HP-LaserJet-1010-to-Windows-7
# Connect-Printer-to-iPad
# Connect-the-HP-Deskjet-3050-to-a-Wireless-Router
# Connect-to-a-Network-Printer
# Connect-to-an-Epson-XP%E2%80%93400
# Create-a-Basic-3D-Solar-Printer
# Decide-Whether-to-Buy-an-Inkjet-Printer-or-a-Laser-Printer
# Decide-Whether-to-Print-Something-Out
# Directly-Email-a-Scanned-Document-with-an-HP-Deskjet-5525
# Download-Drivers-for-a-Canon-Inkjet-Printer
# Download-Drivers-for-a-Lexmark-Laser-Printer
# Download-Drivers-for-an-Epson-All-In-One-Printer
# Download-Drivers-for-an-Inkjet-Printer
# Email-a-Scanned-Document-With-Photosmart
# Extend-Toner-Life
# Fax-on-the-Canon-MX410
# 830
# Find-the-Right-and-Low-Cost-Inkjet-Cartridges
# Find-Your-Printer-IP-Address
# Fix-a-Print-Spooler
# Fix-an-Offline-Printer
# Get-a-Meter-Reading-for-a-Gei-2436,-Gei-3636-or-Gei-2900-Wide-Format-Engineering-Copier
# Handle-Your-PVC-Cards-to-Add-to-the-Life-of-Your-Card-Printer
# Improve-the-Print-Quality-of-an-Inkjet-Printer
# Improve-the-Print-Quality-on-a-Laser-Printer
# Install-a-Network-Printer
# Install-a-Printer-Driver-to-Ubuntu
# Install-a-Printer-on-a-Windows-PC
# Install-a-Printer-Without-the-Installation-Disk
# Install-a-Printer
# Install-an-HP-Deskjet-3050A
# Install-Canon-Wireless-Printer
# Install-HPLIP-to-Linux
# Load-Envelopes-into-an-Inkjet-Printer
# Load-Labels-Into-an-Inkjet-Printer
# Make-a-Vapor-Catcher-for-Markem-Imaje-9030
# Make-the-HP-2015-Printer-Print-an-Adobe-Acrobat-Reader-File
# 1151
# Mobile-Print-at-SUNY-Buffalo-State
# Network-a-PC-With-a-Mac-to-Share-Files-and-Printers
# Print-8.5-x-5.5
# Print-a-List-of-Files
# Print-an-Index-Sheet-Using-the-HP-Photosmart-8150
# Print-Brochures
# Print-Documents-Wirelessly-on-an-iPad-with-HP-All-in-One-Printer-Remote
# Print-Double-Sided-Documents-on-Any-Printer
# Print-Double-Sided
# Print-Files-Containing-Custom-Fonts-in-School
# Print-from-an-Android-Phone-or-Tablet
# Print-High-Quality-Photos-Using-an-Inkjet-Printer
# Print-in-Black-and-White-on-Epson-Printers
# Print-on-Individual-Business-Cards
# Print-Pictures-from-Your-Phone
# Print-Pictures-in-Black-and-White
# Print-Thumbnails
# Print-Tickets
# Print-Wirelessly-from-an-iPad-with-HP-Eprint-App
# Properly-Clean-an-Inkjet-or-Solvent-Wide-Format-Printer
# 1471
# Put-Ink-Cartridges-in-a-Printer
# Refill-a-Laser-Printer-or-Copier-Toner-Cartridge
# Remove-an-Undeletable-Stuck-Document-from-the-Windows-Printer-Queue
# Repair-a-HP-Series-600-Printer-With-a-Malfunctioning-Paper-Feed-Mechanism
# Replace-a-Toner-Cartridge-in-a-Canon-Laser-Printer
# Replace-a-Toner-Cartridge-in-a-Laser-Printer
# Reset-an-HP-Photosmart-Printer
# Reset-the-Okidata-Microline-320-Turbo-to-the-Factory-Default-Settings
# Save-Printer-Ink
# Scan-a-Document-on-a-Canon-Printer
# Scan-a-Document-Wirelessly-to-Your-Computer-with-an-HP-Deskjet-5525
# Scan-and-Print-Pictures-from-a-Computer
# Scan-on-a-Canon-MX410
# Secure-Your-Printing-Jobs-with-a-PIN
# Set-a-File-up-for-Printing-With-Bleeds
# Set-up-a-Printer-on-a-Network-With-Windows-7
# Set-Up-a-Printer
# Set-Up-a-Wireless-Printer-Connection
# Set-up-Automatic-Printing-from-a-Mobile-Device
# Set-Up-Remote-Desktop-Printing
# 1784
# Set-up-Your-Laptop-to-Print-Wirelessly
# Share-a-Printer-on-a-Network
# Share-a-Printer
# Share-a-USB-Printer
# Sharpen-Your-Printer-Image
# Solve-Common-Printer-Problems
# Stop-Printer-Spooling-on-a-Windows-Computer
# Stop-Your-Laser-Printer-from-Smearing
# Understand-Photographic-Laser-Printing
# Understand-the-Advantages-of-Laser-Printers
# Use-a-Yudu-Screen-Printing-Machine
# Use-HP-Universal-Printing
# Use-Print-Friendly
# View-the-Remaining-Amount-of-Ink-Without-Printing-a-Test-Page-on-an-HP-Photosmart-5180

# %%
workbook.close()
